# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from PIL import Image

# %%
data1 = np.load('/data0/BraTS2020/testImage/BraTS20_Validation_113_88.npy')
# data2 = np.load('/data0/BraTS2020/testImage/BraTS20_Validation_001_115.npy')

# %%
# data1 = np.load('/data0/LUNA16PROPOCESSPATH/subset0/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260_clean.npy')
print(data1.shape)
im = Image.fromarray(data1[1])
im.save("test.jpg")
# Out:
# (160, 160, 4)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/dc2-user/anaconda3/envs/py36/lib/python3.6/site-packages/PIL/JpegImagePlugin.py in _save(im, fp, filename)
#     632     try:
# --> 633         rawmode = RAWMODE[im.mode]
#     634     except KeyError as e:
#
# KeyError: 'F'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-7-d90d46eebb62> in <module>
#       2 print(data1.shape)
#       3 im = Image.fromarray(data1[1])
# ----> 4 im.save("test.jpg")
#
# /home/dc2-user/anaconda3/envs/py36/lib/python3.6/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    2170
#    2171         try:
# -> 2172             save_handler(self, fp, filename)
#    2173         finally:
#    2174             # do what we can to clean up
#
# ...

# %%
data1=data1+np.min(data1)

# %%
import cv2
plt.figure(figsize=(12,12))
plt.subplot(1,3,1)
plt.imshow(data1[:,:,0],'gray') # 显示图片
plt.subplot(1,3,2)
img = cv2.imread("test1.png")
plt.imshow(img[:,:,1],'gray') # 显示图片
plt.subplot(1,3,3)
plt.imshow(data1[:,:,0]*(img[:,:,1]==0),'gray') # 显示图片
plt.savefig("test.png")
plt.show()

# %%
print(data1.shape)
print(data2.shape)
# Out:
# (160, 160, 4)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-913340611469> in <module>
#       1 print(data1.shape)
# ----> 2 print(data2.shape)
#
# NameError: name 'data2' is not defined

# %%
print(data1[:,:,0].max())
plt.imshow(data1[:,:,2]) # 显示图片
plt.axis('off') # 不显示坐标轴
plt.show()
# Out:
# 2.1154973034285467

# %%
plt.imshow(data2[:,:,0],cmap="gray") # 显示图片
plt.axis('off') # 不显示坐标轴
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-fc4438f33b24> in <module>
# ----> 1 plt.imshow(data2[:,:,0],cmap="gray") # 显示图片
#       2 plt.axis('off') # 不显示坐标轴
#       3 plt.show()
#
# NameError: name 'data2' is not defined

# %%
import SimpleITK as sitk

# %%
info = sitk.ReadImage('/data0/BraTS2020/brats_train/BraTS20_Training_100/BraTS20_Training_100_t1.nii.gz')
flair_array = sitk.GetArrayFromImage(info)

# %%
print(flair_array.min())
# Out:
# 0

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
 
# src = cv2.imread(info)
# cv2.imshow("src", src)
flair_array_ = flair_array.ravel()
data = data1[:,:,0]
print(data.shape)
data = data.ravel()
# print(type(src))
 
plt.hist(data,20)
plt.show()

cv2.waitKey(0)
# Out:
# (160, 160)
# -1

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
data1 = np.load('/data0/LUNA16PROPOCESSPATH/subset0/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260_clean.npy')

# %%
print(data1.shape)

# %%
data1.reshape(288,212,344)

# %%
data1.shape

# %%
plt.imshow(data1[0][1],cmap="gray") # 显示图片
plt.axis('off') # 不显示坐标轴
plt.show()

# %%
# -*- coding: utf-8 -*-
# Author:  @ MuLun_Zhu
# reader > programmer > machine
# @Time :  2021/6/9 12:25 上午
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = np.load("/data0/BraTS2020/testImage/BraTS20_Validation_001_113.npy")
print(img.shape)
img = img[:,:,0]
print(img.max())
print(img.min())
print(img.shape)
plt.figure(figsize=(12,12))
plt.subplot(111)
plt.axis('off')
plt.imshow(img,'gray')
plt.savefig("./name.jpg")
plt.show()
# cv2.imwrite("./name.jpg", img)
# Out:
# (160, 160, 4)
# 2.3575983491275796
# -9.0
# (160, 160)
